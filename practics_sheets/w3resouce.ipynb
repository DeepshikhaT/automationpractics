# %%
import re
def text_match(text):
        patterns = '^[a-z]'
        if re.search(patterns,  text):
                return 'Found a match!'
        else:
                return('Not matched!')

print(text_match("The quick brown fox jumps over the lazy dog _0."))
print(text_match("Python_Exercises_1"))
# Out:
# Not matched!
# Not matched!

# %%
def num_test(num):
    temp=0
    if num ==35:
        temp +=1
    return temp
print(num_test(35))
# Out:
# 1

# %%
import re
ip = "216.08.094.196"
string = re.sub('\.0*', '.', ip)
print(string)
# Out:
# 216.8.94.1960

# %%
import re
def end_num(string):
    text = re.compile(r".*[0-9]$")
    if text.match(string):
        return True
    else:
        return False

print(end_num('abcdef'))
print(end_num('abcdef6'))
# Out:
# False
# True

# %%
import re
results = re.finditer(r"([0-9]{1,3})", "Exercises number 1, 12, 13, and 345 are important")
print("Number of length 1 to 3")
for n in results:
     print(n.group(0))
# Out:
# Number of length 1 to 3
# 1
# 12
# 13
# 345

# %%
import re
patterns=['fox','dog','horse']
text = 'The quick brown fox jumps over the lazy dog.'
for pattern in patterns:
    if re.search(pattern,text):
        print('match')
    else:
        print('not match')
# Out:
# match
# match
# not match

# %%
import re
pattern = 'fox'
text = 'The quick brown fox jumps over the lazy dog.'
match = re.search(pattern, text)
print(match)
# Out:
# <re.Match object; span=(16, 19), match='fox'>

# %%
s=match.start()
e=match.end()
print(s,e)
# Out:
# 16 19

# %%
print(f'fount {text }in {pattern} strt {s} to {e}')
# Out:
# fount The quick brown fox jumps over the lazy dog.in fox strt 16 to 19

# %%
import re
text = 'Python exercises, PHP exercises, C# exercises'
pattern = 'exercises'
match = re.finditer(pattern,text)
print(match)
for match in re.finditer(pattern, text):
    print('Found "%s"' % match)
# Out:
# ...
# Found "<re.Match object; span=(7, 16), match='exercises'>"
# Found "<re.Match object; span=(22, 31), match='exercises'>"
# Found "<re.Match object; span=(36, 45), match='exercises'>"

# %%
import re
def extract_date(url):
        return re.findall(r'(\d{4})/(\d{1,2})/(\d{1,2})/', url)
url1= "https://www.washingtonpost.com/news/football-insider/wp/2016/09/02/odell-beckhams-fame-rests-on-one-stupid-little-ball-josh-norman-tells-author/"
print(extract_date(url1))
# Out:
# [('2016', '09', '02')]

# %%
import re
def change_date_format(dt):
        return re.sub(r'(\d{4})-(\d{1,2})-(\d{1,2})','\\3-\\2-\\1', dt)
dt1 = "2026-01-02"
print("Original date in YYY-MM-DD Format: ",dt1)
print("New date in DD-MM-YYYY Format: ",change_date_format(dt1))
# Out:
# Original date in YYY-MM-DD Format:  2026-01-02
# New date in DD-MM-YYYY Format:  02-01-2026

# %%
import re
# Sample string.
text = "Ten 10,Twenty 20,Thirty 30"
result = re.split("\D+", text)
# Print results.
print(result)
for element in result:
    print(element)
# Out:
# ['', '10', '20', '30']
#
# 10
# 20
# 30

# %%
def camel_to_snake(text):
        import re
        str1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', text)
        print(str1)
        return re.sub('([a-z0-9])([A-Z])', r'\1_\2', str1).lower()

print(camel_to_snake('PythonexerCises'))
# Out:
# Pythonexer_Cises
# pythonexer_cises

# %%
def snake_to_camel(word):
        import re
        print(word.split('_'))
        return ''.join(x.capitalize() for x in word.split('_'))

print(snake_to_camel('python_exercises'))
# Out:
# ['python', 'exercises']
# PythonExercises

# %%
import re
text1 = '"Python", "PHP", "Java"'
str1= re.findall(r'(\b\w+\b)',text1)
print(str1)
print(re.findall(r'"(.*?)"', text1))
# Out:
# ['Python', 'PHP', 'Java']
# ['Python', 'PHP', 'Java']

# %%
import re
text1 = '**//Python Exercises// - 12.'
pattern = re.sub('[\W+]','',text1)
print(pattern)
# Out:
# PythonExercises12

# %%
import re
text = "PythonTutorialAndExercises"
print(re.findall('[A-Z][^A-Z]*', text))

# %%
import re
text = "PythonTutorialAndExercises"
print(re.findall('[A-Z][a-z]*', text))
# Out:
# ['Python', 'Tutorial', 'And', 'Exercises']

# %%
# Import the Counter class from the collections module
from collections import Counter

# Create a Counter object 'c' with specified initial counts for keys 'p', 'q', 'r', and 's'
c = Counter(p=4, q=2, r=0, s=-2)

# Print the elements in the Counter 'c' as a list
print(list(c.elements()))
# Out:
# ['p', 'p', 'p', 'p', 'q', 'q']

# %%
u = Counter(s=-1)
print(list(u.elements()))
# Out:
# []

# %%
s = 'lkseropewdssafsdfafkpwe'
print(Counter(s).most_common(3))
# Out:
# [('s', 4), ('e', 3), ('f', 3)]

# %%
from collections import deque
dq = deque('aeiou')
for i in dq:
    print(i)
# Out:
# a
# e
# i
# o
# u

# %%
def last(n):
    return n[-1]
def sort_list_last(list_of_tuple):
    return sorted(list_of_tuple,key=last)

# %%
print(sort_list_last([(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]))
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %%
# Define a function called 'last' that takes a single argument 'n' and returns the last element of 'n'
def last(n):
    return n[-1]

# Define a function called 'sort_list_last' that takes a list of tuples 'tuples' as input
def sort_list_last(tuples):
    # Sort the list of tuples 'tuples' using the 'last' function as the key for sorting
    return sorted(tuples, key=last)

# Call the 'sort_list_last' function with a list of tuples as input and print the sorted result
print(sort_list_last([(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]))
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %%
a = [10, 20, 30, 20, 10, 50, 60, 40, 80, 50, 40]
dup_items=set()
uniq_items=[]
for x in a:
    if x not in dup_items:
        uniq_items.append(x)
        dup_items.add(x)
print(dup_items)
# Out:
# {40, 10, 80, 50, 20, 60, 30}

# %%
# Define a function called 'long_words' that takes an integer 'n' and a string 'str' as input
def long_words(n, str):
    # Create an empty list 'word_len' to store words longer than 'n' characters
    word_len = []

    # Split the input string 'str' into a list of words using space as the delimiter
    txt = str.split(" ")

    # Iterate through each word 'x' in the list of words 'txt'
    for x in txt:
        # Check if the length of the current word 'x' is greater than 'n'
        if len(x) > n:
            # If the word is longer than 'n' characters, add it to the 'word_len' list
            word_len.append(x)

    # Return the list of words longer than 'n' characters
    return word_len

# Call the 'long_words' function with an 'n' value of 3 and a string as input, and print the result
print(long_words(3, "The quick brown fox jumps over the lazy dog"))
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']

# %%
 value= ['256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM',
 '256QAM']

value_set = set(value)

# %%
print(value_set)
# Out:
# {'256QAM'}

# %%
len(value_set)
# Out:
# 1

# %%
value.count('256QAM')
# Out:
# 624

# %%
len(value)
# Out:
# 624

# %%
mod_value= ['256QAM']*1000

# %%
mod_value
# Out:
# ['256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
#  '256QAM',
# ...

# %%
expect_mod ='256qam'
expect_mod.upper()
# Out:
# '256QAM'

# %%
def test(nums):
    result =[]
    for i,x in enumerate(sorted(nums)):
        for y in nums[i+1:]:
            if y == x+3:
                result.append([x,y])
    return  result

# %%
nums = [0, 3, 4, 7, 9]
print(test(nums))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 nums = [0, 3, 4, 7, 9]
# ----> 2 print(test(nums))
#
# NameError: name 'test' is not defined

# %%
 arr = ['27',
 '31',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '31',
 '27',
 '27',
 '31',
 '27',
 '27',
 '25',
 '27',
 '26',
 '27',
 '31',
 '26',
 '26',
 '26',
 '27',
 '26',
 '27',
 '27',
 '26',
 '26',
 '31',
 '26',
 '26',
 '26',
 '27',
 '26',
 '25',
 '27',
 '26',
 '26',
 '26',
 '26',
 '26',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '25',
 '27',
 '27',
 '27',
 '31',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '27',
 '31',
 '27',
 '27',
 '31',
 '27',
 '27',
 '25',
 '27',
 '26',
 '26',
 '31',
 '26',
 '26',
 '27',
 '27',
 '27',
 '27']

# %%
import numpy as np

# %%
print(np.arr[dtype])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(np.arr[dtype])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arr'

# %%
np.mean(np.array([arr]))
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 np.mean(np.array([arr]))
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:181, in _mean(a, axis, dtype, out, keepdims, where)
#     178         dtype = mu.dtype('f4')
#     179         is_float16_result = True
# --> 181 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     182 if isinstance(ret, mu.ndarray):
# ...

# %%
a=np.mean(np.array([arr]).astype('f'))

# %%
print(a)
# Out:
# 27.09091

# %%
print(a.dtype)
# Out:
# float32

# %%
s = '34'
float(s)
# Out:
# 34.0

# %%
a = [' 27','28',' ']
b =sum([float(i) for i in a if i.strip()!=''])/len(a)

# %%
print(b)
# Out:
# 18.333333333333332

# %%
 bbmnod_modules=[{'cabinetId': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1',
                'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1',
                'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1'},
  'fullCapacityInUse': 'Yes',
  'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-3',
         'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5',
         'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5'},
  'ports': [{'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/SFP_R-1',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/SFP_R-1'},
             'label': 'RF1'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/SFP_R-2',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/SFP_R-2'},
             'label': 'RF2'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/SFP_R-3',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/SFP_R-3'},
             'label': 'RF3'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-3/RF4',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-3/CONNECTOR_L-4',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/RF4'},
             'label': 'RF4'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-3/RF5',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-3/CONNECTOR_L-5',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/RF5'},
             'label': 'RF5'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-3/RF6',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-3/CONNECTOR_L-6',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-5/RF6'},
             'label': 'RF6'}],
  'productCode': '473096A.103',
  'productName': 'ABIA AirScale Capacity',
  'serialNumber': 'AH181111039',
  'status': {'administrativeState': 'Unlocked',
             'operationalState': 'enabled',
             'proceduralStatus': 'configured',
             'usageState': 'Active'}},
 {'cabinetId': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1',
                'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1',
                'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1'},
  'fullCapacityInUse': 'Yes',
  'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5',
         'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2',
         'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2'},
  'ports': [{'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/SFP_R-1',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/SFP_R-1'},
             'label': 'RF1'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF2',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-2',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF2'},
             'label': 'RF2'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF3',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-3',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF3'},
             'label': 'RF3'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF4',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-4',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF4'},
             'label': 'RF4'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF5',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-5',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF5'},
             'label': 'RF5'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF6',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-6',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF6'},
             'label': 'RF6'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/SFP_R-7',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/SFP_R-7'},
             'label': 'RF7'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF8',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-8',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF8'},
             'label': 'RF8'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-5/RF9',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-9',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-2/RF9'},
             'label': 'RF9'}],
  'productCode': '475266A.102',
  'productName': 'ABIO AirScale Capacity',
  'serialNumber': 'L1210400848',
  'status': {'administrativeState': 'Unlocked',
             'operationalState': 'enabled',
             'proceduralStatus': 'configured',
             'usageState': 'Active'}},
 {'cabinetId': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1',
                'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1',
                'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1'},
  'fullCapacityInUse': 'Yes',
  'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-1',
         'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3',
         'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3'},
  'ports': [{'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-1',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-1'},
             'label': 'RF1'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-2',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-2'},
             'label': 'RF2'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-3',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-3'},
             'label': 'RF3'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-1/RF4',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-4',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/RF4'},
             'label': 'RF4'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-1/RF5',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-5',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/RF5'},
             'label': 'RF5'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-1/RF6',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-1/CONNECTOR_L-6',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/RF6'},
             'label': 'RF6'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-7',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-7'},
             'label': 'RF7'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-8',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-8'},
             'label': 'RF8'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-9',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-3/SFP_R-9'},
             'label': 'RF9'}],
  'productCode': '475266A.104',
  'productName': 'ABIO AirScale Capacity',
  'serialNumber': 'L1214403610',
  'status': {'administrativeState': 'Unlocked',
             'operationalState': 'enabled',
             'proceduralStatus': 'configured',
             'usageState': 'Active'}},
 {'cabinetId': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1',
                'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1',
                'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1'},
  'fullCapacityInUse': 'Yes',
  'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4',
         'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1',
         'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1'},
  'ports': [{'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/SFP_R-1',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/SFP_R-1'},
             'label': 'RF1'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF2',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-2',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF2'},
             'label': 'RF2'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF3',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-3',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF3'},
             'label': 'RF3'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF4',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-4',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF4'},
             'label': 'RF4'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF5',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-5',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF5'},
             'label': 'RF5'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF6',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-6',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF6'},
             'label': 'RF6'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/SFP_R-7',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/SFP_R-7'},
             'label': 'RF7'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF8',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-8',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF8'},
             'label': 'RF8'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-4/RF9',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-4/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-9',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-1/RF9'},
             'label': 'RF9'}],
  'productCode': '475266A.104',
  'productName': 'ABIO AirScale Capacity',
  'serialNumber': 'L1214403554',
  'status': {'administrativeState': 'Unlocked',
             'operationalState': 'enabled',
             'proceduralStatus': 'configured',
             'usageState': 'Active'}},
 {'cabinetId': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1',
                'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1',
                'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1'},
  'fullCapacityInUse': 'Yes',
  'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2',
         'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4',
         'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4'},
  'ports': [{'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/SFP_R-1',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/SFP_R-1'},
             'label': 'RF1'},
            {'id': {'internal': '/MRBTS-1/RAT-1/RUNTIME_VIEW-1/MRBTS_R-1/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/SFP_R-2',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/SFP_R-2'},
             'label': 'RF2'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF3',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-3',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF3'},
             'label': 'RF3'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF4',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-4',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF4'},
             'label': 'RF4'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF5',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-5',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF5'},
             'label': 'RF5'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF6',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-6',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF6'},
             'label': 'RF6'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF7',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-7',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF7'},
             'label': 'RF7'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF8',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-8',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF8'},
             'label': 'RF8'},
            {'id': {'configuration': 'MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-2/RF9',
                    'internal': '/MRBTS-1/RAT-1/BTS_L-1/EQM_L-1/CABINET_L-1/BBMOD_L-2/CONNECTOR_L-9',
                    'runtime': 'MRBTS-4004880/EQM_R-1/APEQM_R-1/CABINET_R-1/BBMOD_R-4/RF9'},
             'label': 'RF9'}],
  'productCode': '475266A.104',
  'productName': 'ABIO AirScale Capacity',
  'serialNumber': 'L1214403617',
  'status': {'administrativeState': 'Unlocked',
             'operationalState': 'enabled',
             'proceduralStatus': 'configured',
             'usageState': 'Active'}}]

# %%
mod_name =next((m["id"]["configuration"] for m in bbmnod_modules if m["id"]["configuration"].rpartition("-")[-1] == "3"), None)

# %%
print(mod_name)
# Out:
# MRBTS-4004880/EQM-1/APEQM-1/CABINET-1/BBMOD-3

# %%
###try to search list

# %%
s= 'w3resource.com'
len(s)
# Out:
# 14

# %%
def check_set_value(setA):
    
    
    return all(map(lambda x: 18<=x<=22,setA))

# %%
setA = {18,56,20,21}
print(check_set_value(setA))
# Out:
# False

# %%
interRankSwitchBlockThresholds={'rankSwitchBlockBlerHighThres' : 20,
                               'rankSwitchBlockBlerLowThres' : 30,
                               'rankSwitchBlockMcsThres1' :22,
                               'rankSwitchBlockMcsThres2': 18}

# %%
print(interRankSwitchBlockThresholds)
# Out:
# {'rankSwitchBlockBlerHighThres': 20, 'rankSwitchBlockBlerLowThres': 30, 'rankSwitchBlockMcsThres1': 22, 'rankSwitchBlockMcsThres2': 18}

# %%
cqi_derived_msc=set()
rank_switch=set()
num_of_layer=set()
events=[{'eventHeader': {'hfnTickCount': 65110, 'sfn': 1006, 'slot': 2, 'emCoreId': 4, 'rnti': 1687, 'lcrId': 201, 'physCellId': 201}, 'cellDbIndex': 0, 'subcellId': 3, 'ueType': 'SCELL', 'priorityIndex': 15, 'cqiDerivedMcs': 27, 'rrmDlUsedMcs': 27, 'rrmDlProposedMcs': 27,'rankSwitchBlocking' : 1, 'ptrsFlagDlProposedMcs': 'PTRS_OFF', 'isDefaultMcsProposed': 0, 'isValidWhatIsProposed': 1, 'isScalingDone': 0, 'mcsTable': 'QAM256', 'rrmDlScaledMcs': 27, 'pcellSlotsPerFrame': 20, 'remainingDataVolumeDl': 373480, 'maxDataVolumeDl': 684835, 'rrmDlBufBasedDowngradedMcs': 27, 'DlBufBasedDowngradedTbSize': 311368, 'numOfPrb': 160, 'startPrb': 0, 'rat0Bitmap': 1023, 'tbSize': 311368, 'effectiveCodeRate': 0.924124, 'proposedCodeRate': 0.936979, 'numCdmGroupNoData': 1, 'muStatus': 'NONE', 'beamType': 'SSB', 'rtBeamFailureReason': 'PATTERNIDINVALID', 'doaH': 3.40282e+38, 'doaV': 3.40282e+38, 'bestPatternId': 65535, 'rrmBufferedDataDlTotal': 141022, 'bufferSplitFactorForCore': 1, 'txNumber': 1, 'dlHarqProcessIndex': 2, 'dlHarqBufferIndex': 25, 'SLIV': 53, 'K1': 9, 'redundancyVersion': 0, 'numOfLayers': 'RANK2', 'PMI': 0, 'antPort': 49152, 'nscId': 0, 'beamId': 0, 'beamId2': 0, 'pdcchBeamId': 0, 'pucchBeamId': 0, 'csiBeamId': 0, 'beamInfoForRtBeamForEirp': {'beamId': 65535, 'state': 'BEAM_ID_IDLE'}, 'streamConfig': {'numStreamIndex': 4, 'streamIndex1': 0, 'streamIndex2': 1, 'streamIndex3': 2, 'streamIndex4': 3, 'patternId1': 0, 'patternId2': 0}, 'macCe': {'tac': 65535, 'brsBeamChange': 65535, 'brrsBeamChange': 255, 'numTciStateInd': 0, 'hasCri': 0, 'hasSCellActDeact': 0, 'sCellActDeact': 0, 'sCellActDeact4Byte': 0}, 'rrmDeltaCqiMuMimo': 0, 'rrmCorrAvgCqi': 13.5138, 'rrmCqiCorrection': -0.0653595, 'rrmMuOrSuAvgCqi': 12, 'rrmHighNackDtxInd': 0, 'startCce': 10, 'pdcchStartSymbol': 0, 'searchSpaceType': 'UE_SPECIFIC', 'searchSpaceId': 8, 'dciFormat': 'DL_11', 'scheduledBearers': [{'lcId': 4, 'bsrSlot': 5, 'bsrSfn': 39321, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 5, 'bsrSlot': 1, 'bsrSfn': 1006, 'scheduledBytesPerBearer': 38921, 'remainingBytesPerBearerInFdEoBuffer': 102101, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}], 'aggregationLevel': 2, 'ueBwpId': 1, 'cellBwpId': 1, 'numOf5qi1Prb': 0, 'numOfNonVoNRGbrPrb': 0, 'cqiAlSelection': 16.1976, 'cqiPdcchOffset': 0, 'dciSizeOffset': -0.24, 'pdcchCqi': 14.9376, 'cqiPdcchReduction': 255, 'suPdschTbTransmitPower': -331, 'muPdschPowerOffset': 0, 'rrmtotalDrbBufferedBytes': 141022, 'bestBeamPowerOffset': 0, 'isRetxDownGradeNewTx': 1, 'PRBCandRetx': 0, 'PRBMinRetx': 0, 'PRBMaxCodeRateRetx': 0, 'adaptRetxStatus': 'NOTACTIVATE', 'codingGainStatus': 'NOTACTIVATE', 'maxHarqTxNum': 8, 'supportOfRedCap': 0, 'targetBLER': 0.1, 'laMode': 'BASICRELIABILITY', 'deltaCqiStepScalingFactor': 1},
{'eventHeader': {'hfnTickCount': 65110, 'sfn': 1006, 'slot': 3, 'emCoreId': 4, 'rnti': 1687, 'lcrId': 201, 'physCellId': 201}, 'cellDbIndex': 0, 'subcellId': 3, 'ueType': 'SCELL', 'priorityIndex': 15, 'cqiDerivedMcs': 27, 'rrmDlUsedMcs': 27, 'rrmDlProposedMcs': 27, 'rankSwitchBlocking' : 1, 'ptrsFlagDlProposedMcs': 'PTRS_OFF', 'isDefaultMcsProposed': 0, 'isValidWhatIsProposed': 1, 'isScalingDone': 0, 'mcsTable': 'QAM256', 'rrmDlScaledMcs': 27, 'pcellSlotsPerFrame': 20, 'remainingDataVolumeDl': 373480, 'maxDataVolumeDl': 684835, 'rrmDlBufBasedDowngradedMcs': 27, 'DlBufBasedDowngradedTbSize': 311368, 'numOfPrb': 160, 'startPrb': 0, 'rat0Bitmap': 1023, 'tbSize': 311368, 'effectiveCodeRate': 0.924124, 'proposedCodeRate': 0.936979, 'numCdmGroupNoData': 1, 'muStatus': 'NONE', 'beamType': 'SSB', 'rtBeamFailureReason': 'PATTERNIDINVALID', 'doaH': 3.40282e+38, 'doaV': 3.40282e+38, 'bestPatternId': 65535, 'rrmBufferedDataDlTotal': 325146, 'bufferSplitFactorForCore': 1, 'txNumber': 1, 'dlHarqProcessIndex': 3, 'dlHarqBufferIndex': 2, 'SLIV': 53, 'K1': 7, 'redundancyVersion': 0, 'numOfLayers': 'RANK2', 'PMI': 0, 'antPort': 49152, 'nscId': 0, 'beamId': 0, 'beamId2': 0, 'pdcchBeamId': 0, 'pucchBeamId': 0, 'csiBeamId': 0, 'beamInfoForRtBeamForEirp': {'beamId': 65535, 'state': 'BEAM_ID_IDLE'}, 'streamConfig': {'numStreamIndex': 4, 'streamIndex1': 0, 'streamIndex2': 1, 'streamIndex3': 2, 'streamIndex4': 3, 'patternId1': 0, 'patternId2': 0}, 'macCe': {'tac': 65535, 'brsBeamChange': 65535, 'brrsBeamChange': 255, 'numTciStateInd': 0, 'hasCri': 0, 'hasSCellActDeact': 0, 'sCellActDeact': 0, 'sCellActDeact4Byte': 0}, 'rrmDeltaCqiMuMimo': 0, 'rrmCorrAvgCqi': 13.7589, 'rrmCqiCorrection': 0.179739, 'rrmMuOrSuAvgCqi': 12, 'rrmHighNackDtxInd': 0, 'startCce': 2, 'pdcchStartSymbol': 0, 'searchSpaceType': 'UE_SPECIFIC', 'searchSpaceId': 8, 'dciFormat': 'DL_11', 'scheduledBearers': [{'lcId': 4, 'bsrSlot': 5, 'bsrSfn': 39321, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 5, 'bsrSlot': 2, 'bsrSfn': 1006, 'scheduledBytesPerBearer': 38921, 'remainingBytesPerBearerInFdEoBuffer': 286225, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}], 'aggregationLevel': 2, 'ueBwpId': 1, 'cellBwpId': 1, 'numOf5qi1Prb': 0, 'numOfNonVoNRGbrPrb': 0, 'cqiAlSelection': 16.1976, 'cqiPdcchOffset': 0, 'dciSizeOffset': -0.24, 'pdcchCqi': 14.9376, 'cqiPdcchReduction': 255, 'suPdschTbTransmitPower': -331, 'muPdschPowerOffset': 0, 'rrmtotalDrbBufferedBytes': 325146, 'bestBeamPowerOffset': 0, 'isRetxDownGradeNewTx': 1, 'PRBCandRetx': 0, 'PRBMinRetx': 0, 'PRBMaxCodeRateRetx': 0, 'adaptRetxStatus': 'NOTACTIVATE', 'codingGainStatus': 'NOTACTIVATE', 'maxHarqTxNum': 8, 'supportOfRedCap': 0, 'targetBLER': 0.1, 'laMode': 'BASICRELIABILITY', 'deltaCqiStepScalingFactor': 1},
{'eventHeader': {'hfnTickCount': 65110, 'sfn': 1006, 'slot': 4, 'emCoreId': 4, 'rnti': 1687, 'lcrId': 201, 'physCellId': 201}, 'cellDbIndex': 0, 'subcellId': 3, 'ueType': 'SCELL', 'priorityIndex': 15, 'cqiDerivedMcs': 26, 'rrmDlUsedMcs': 26, 'rrmDlProposedMcs': 26, 'rankSwitchBlocking' : 1,'ptrsFlagDlProposedMcs': 'PTRS_OFF', 'isDefaultMcsProposed': 0, 'isValidWhatIsProposed': 1, 'isScalingDone': 0, 'mcsTable': 'QAM256', 'rrmDlScaledMcs': 26, 'pcellSlotsPerFrame': 20, 'remainingDataVolumeDl': 381607, 'maxDataVolumeDl': 684835, 'rrmDlBufBasedDowngradedMcs': 26, 'DlBufBasedDowngradedTbSize': 303240, 'numOfPrb': 160, 'startPrb': 0, 'rat0Bitmap': 1023, 'tbSize': 303240, 'effectiveCodeRate': 0.9, 'proposedCodeRate': 0.910208, 'numCdmGroupNoData': 1, 'muStatus': 'NONE', 'beamType': 'SSB', 'rtBeamFailureReason': 'PATTERNIDINVALID', 'doaH': 3.40282e+38, 'doaV': 3.40282e+38, 'bestPatternId': 65535, 'rrmBufferedDataDlTotal': 286232, 'bufferSplitFactorForCore': 1, 'txNumber': 1, 'dlHarqProcessIndex': 4, 'dlHarqBufferIndex': 16, 'SLIV': 53, 'K1': 6, 'redundancyVersion': 0, 'numOfLayers': 'RANK2', 'PMI': 0, 'antPort': 49152, 'nscId': 0, 'beamId': 0, 'beamId2': 0, 'pdcchBeamId': 0, 'pucchBeamId': 0, 'csiBeamId': 0, 'beamInfoForRtBeamForEirp': {'beamId': 65535, 'state': 'BEAM_ID_IDLE'}, 'streamConfig': {'numStreamIndex': 4, 'streamIndex1': 0, 'streamIndex2': 1, 'streamIndex3': 2, 'streamIndex4': 3, 'patternId1': 0, 'patternId2': 0}, 'macCe': {'tac': 65535, 'brsBeamChange': 65535, 'brrsBeamChange': 255, 'numTciStateInd': 0, 'hasCri': 0, 'hasSCellActDeact': 0, 'sCellActDeact': 0, 'sCellActDeact4Byte': 0}, 'rrmDeltaCqiMuMimo': 0, 'rrmCorrAvgCqi': 13.4321, 'rrmCqiCorrection': -0.147059, 'rrmMuOrSuAvgCqi': 12, 'rrmHighNackDtxInd': 0, 'startCce': 6, 'pdcchStartSymbol': 0, 'searchSpaceType': 'UE_SPECIFIC', 'searchSpaceId': 8, 'dciFormat': 'DL_11', 'scheduledBearers': [{'lcId': 4, 'bsrSlot': 5, 'bsrSfn': 39321, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 5, 'bsrSlot': 3, 'bsrSfn': 1006, 'scheduledBytesPerBearer': 37905, 'remainingBytesPerBearerInFdEoBuffer': 248327, 'rlcStatusPduLength': 25217}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}, {'lcId': 255, 'bsrSlot': 255, 'bsrSfn': 65535, 'scheduledBytesPerBearer': 0, 'remainingBytesPerBearerInFdEoBuffer': 0, 'rlcStatusPduLength': 0}], 'aggregationLevel': 2, 'ueBwpId': 1, 'cellBwpId': 1, 'numOf5qi1Prb': 0, 'numOfNonVoNRGbrPrb': 0, 'cqiAlSelection': 16.1976, 'cqiPdcchOffset': 0, 'dciSizeOffset': -0.24, 'pdcchCqi': 14.9376, 'cqiPdcchReduction': 255, 'suPdschTbTransmitPower': -331, 'muPdschPowerOffset': 0, 'rrmtotalDrbBufferedBytes': 286232, 'bestBeamPowerOffset': 0, 'isRetxDownGradeNewTx': 1, 'PRBCandRetx': 0, 'PRBMinRetx': 0, 'PRBMaxCodeRateRetx': 0, 'adaptRetxStatus': 'NOTACTIVATE', 'codingGainStatus': 'NOTACTIVATE', 'maxHarqTxNum': 8, 'supportOfRedCap': 0, 'targetBLER': 0.1, 'laMode': 'BASICRELIABILITY', 'deltaCqiStepScalingFactor': 1}]
for event in events:
    if event["rankSwitchBlocking"] == 1 and event["numOfLayers"] == 'RANK2':
        cqi_derived_msc.add(event["cqiDerivedMcs"])
        rank_switch.add(event['rankSwitchBlocking'])
        num_of_layer.add(event['numOfLayers'])
    if 'RANK2' not in num_of_layer and int(1) not in rank_switch:
         raise RuntimeError('Desired pkts not present in to the logs')
print(cqi_derived_msc)
print(rank_switch)
print(num_of_layer)
check_msc_range = all(map(lambda x: 18 <= x <= 31, cqi_derived_msc))
if not check_msc_range:
    raise RuntimeError(f"mcs value 18 to 22 not maintaining RANK4 current values {cqi_derived_msc}")
# Out:
# {26, 27}
# {1}
# {'RANK2'}

# %%
used_numrbs_1=['166','166','166','166']

used_numrbs_2=['24','23','24','23']

# %%
sum(list(map(lambda x, y: int(x) + int(y), used_numrbs_1, used_numrbs_2)))/len(used_numrbs_1)
# Out:
# 189.5

# %%
cqi_derived_msc={18, 19, 20, 21, 22, 23, 255}
cqi_derived_msc = {i for i in cqi_derived_msc if int(i) <=21}
print(cqi_derived_msc)
check_msc_range = all(map(lambda x: 18 <= int(x) <= 21, cqi_derived_msc))
print(check_msc_range)
# Out:
# {18, 19, 20, 21}
# True

# %%
all(filter(lambda x: 18 <= int(x) and int(x)!= 255, cqi_derived_msc))
# Out:
# True

# %%
nrsassai_dns = ['MRBTS-4004609/NRBTS-4004609/SNSSAI-1','MRBTS-4004609/NRBTS-4004609/SNSSAI-2']
dn = [dns for dns in nrsassai_dns if dns.rpartition("-")[-1]=='2']
print(dn)
# Out:
# ['MRBTS-4004609/NRBTS-4004609/SNSSAI-2']

# %%
a = hex(13714343)

# %%
sst =0x1

# %%
s1=a[:4]
s2='0x'+a[4:6]
s3='0x'+a[6:]

# %%
print(s1)
print(s2)
print(s3)
# Out:
# 0xd1
# 0x43
# 0xa7

# %%
m='''023 Nov  9  23:12:04.136  [0C]  0xB800  NR5G NAS SM5G Plain OTA Incoming Msg  --  PDU session establishment accept
Subscription ID = 1
Misc ID         = 0
pkt_version = 1 (0x1)
rel_number = 15 (0xf)
rel_version_major = 4 (0x4)
rel_version_minor = 0 (0x0)
prot_disc_type = 14 (0xe)
ext_protocol_disc = 46 (0x2e)
pdu_session_id = 1 (0x1)
proc_trans_id = 134 (0x86)
msg_type = 194 (0xc2) (PDU session establishment accept)
nr5g_smm_msg
  pdu_session_estab_accept
    ssc_mode
      ssc_mode_val = 1 (0x1)
    pdu_session_type
      pdu_session_type = 1 (0x1) (IPv4)
    authorized_qos_rules
      num_recs = 1 (0x1)
      Qos_rule[0]
        qos_rule_id = 1 (0x1)
        rule_opcode = 1 (0x1) (Create new QoS rule)
        DQR = 1 (0x1)
        num_pkt_filter = 1 (0x1)
        pkt_filters[0]
          change_rule
            pkt_filter_dir = 3 (0x3) (bidirectional)
            pkt_filter_id = 1 (0x1)
            num_comps = 1 (0x1)
            pkt_filters_comp_list[0]
              comp_type_id = 1 (0x1) (Match-all)
        rule_precedene_present = 1 (0x1)
        qos_rule_precedence = 254 (0xfe)
        qfi_present = 1 (0x1)
        segregation = 0 (0x0)
        qfi = 9 (0x9)
    session_ambr
      length = 6 (0x6)
      session_ambr_dl_unit = 12 (0xc) (inc in multiple of 4 Gbps)
      session_ambr_dl = 1 (0x1)
      session_ambr_ul_unit = 12 (0xc) (inc in multiple of 4 Gbps)
      session_ambr_ul = 1 (0x1)
    _5gsm_cause_incl = 0 (0x0)
    pdu_addr_incl = 1 (0x1)
    pdu_addr
      length = 5 (0x5)
      si6lla = 0 (0x0)
      pdu_session_type = 1 (0x1)
      ipv4_addr[0] = 10 (0xa)
      ipv4_addr[1] = 48 (0x30)
      ipv4_addr[2] = 49 (0x31)
      ipv4_addr[3] = 33 (0x21)
    rq_timer_incl = 0 (0x0)
    s_nssai_incl = 1 (0x1)
    s_nssai
      s_nssai_len = 4 (0x4)
      sst = 1 (0x1)
      sd[0] = 209 (0xd1)
      sd[1] = 67 (0x43)
      sd[2] = 167 (0xa7)
    always_on_pdu_session_ind_incl = 1 (0x1)
    always_on_pdu_session_ind
      APSI = 0 (0x0) (always-on PDU session not allowed)
    mapped_eps_bearer_context_inc = 0 (0x0)
    eap_msg_incl = 0 (0x0)
    auth_qos_flow_desc_incl = 1 (0x1)
    qos_flow_desc
      num_qos_flow_desc = 1 (0x1)
      qos_flow_description[0]
        qfi = 9 (0x9)
        opcode = 1 (0x1) (Create new QoS flow description)
        e_bit = 1 (0x1)
        num_parameters = 2 (0x2)
        params[0]
          params_id = 1 (0x1)
          length = 1 (0x1)
          qos_flow_desc_params
            _5qi
              _5qi_value = 9 (0x9)
        params[1]
          params_id = 7 (0x7)
          length = 1 (0x1)
          qos_flow_desc_params
            eps_bearer_id
              id = 5 (0x5)
    ext_prot_config_incl = 1 (0x1)
    ext_prot_config
      ext = 1 (0x1)
      conf_prot = 0 (0x0)
      num_recs = 5 (0x5)
      prot_or_container[0]
        id = 32801 (0x8021) (IPCP)
        prot_or_container
          prot_len = 16 (0x10)
          ipcp_prot
            ipcp_prot_id = 3 (0x3) (CONF_NAK)
            identifier = 0 (0x0)
            rfc1332_conf_nak
              num_options = 2 (0x2)
              conf_options[0]
                type = 129 (0x81)
                rfc1877_primary_dns_server_add
                  length = 6 (0x6)
                  ip_addr = 171196171 (0xa343f0b) (10.52.63.11)
              conf_options[1]
                type = 131 (0x83)
                rfc1877_sec_dns_server_add
                  length = 6 (0x6)
                  ip_addr = 181116229 (0xacb9d45) (10.203.157.69)
      prot_or_container[1]
        id = 13 (0xd) (DNS Server IPv4 Address)
        prot_or_container
          prot_len = 4 (0x4)
          container
            container_contents[0] = 10 (0xa)
            container_contents[1] = 52 (0x34)
            container_contents[2] = 63 (0x3f)
            container_contents[3] = 11 (0xb)
      prot_or_container[2]
        id = 13 (0xd) (DNS Server IPv4 Address)
        prot_or_container
          prot_len = 4 (0x4)
          container
            container_contents[0] = 10 (0xa)
            container_contents[1] = 203 (0xcb)
            container_contents[2] = 157 (0x9d)
            container_contents[3] = 69 (0x45)
      prot_or_container[3]
        id = 16 (0x10) (Ipv4 Link MTU Request)
        prot_or_container
          prot_len = 2 (0x2)
          container
            container_contents[0] = 7 (0x7)
            container_contents[1] = 208 (0xd0)
      prot_or_container[4]
        id = 5 (0x5) (Selected Bearer Control Mode)
        prot_or_container
          prot_len = 1 (0x1)
          container
            container_contents[0] = 1 (0x1)
    dnn_incl = 1 (0x1)
    dnn
      dnn_len = 14 (0xe)
      dnn_val[0] = 3 (0x3) (length)
      dnn_val[1] = 102 (0x66) (f)
      dnn_val[2] = 119 (0x77) (w)
      dnn_val[3] = 97 (0x61) (a)
      dnn_val[4] = 5 (0x5) (length)
      dnn_val[5] = 110 (0x6e) (n)
      dnn_val[6] = 111 (0x6f) (o)
      dnn_val[7] = 107 (0x6b) (k)
      dnn_val[8] = 105 (0x69) (i)
      dnn_val[9] = 97 (0x61) (a)
      dnn_val[10] = 3 (0x3) (length)
      dnn_val[11] = 99 (0x63) (c)
      dnn_val[12] = 111 (0x6f) (o)
      dnn_val[13] = 109 (0x6d) (m)
    _5gsm_nwk_feature_support_incl = 0 (0x0)
    srv_plmn_rate_ctrl_incl = 0 (0x0)
    at_sss_container_incl = 0 (0x0)
    ctrl_plane_only_ind_incl = 0 (0x0)
    ip_hc_config_incl = 0 (0x0)
    ethernet_hc_config_incl = 0 (0x0)
    serv_level_aa_incl = 0 (0x0)
    recv_msb_container_incl = 0 (0x0)'''

# %%
patren= re.match(r".*pdu_session_estab_accept.*sd.*= \d+ (\(\)).*sd.*= \d+ (\(0x43\)).*sd.*= \d+ (\(0xa7\))",m,flags=re.DOTALL)

print(patren.groups())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 3
#       1 patren= re.match(r".*pdu_session_estab_accept.*sd.*= \d+ (\(0X[0-9a-fA-F]\)).*sd.*= \d+ (\(0x43\)).*sd.*= \d+ (\(0xa7\))",m,flags=re.DOTALL)
# ----> 3 print(patren.groups())
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %%
patren= re.match(r".*pdu_session_estab_accept.*sd\[0\] = 209\s*\(0xd1\)",m,flags=re.DOTALL)

print(patren)
# Out:
# <re.Match object; span=(0, 1833), match='023 Nov  9  23:12:04.136  [0C]  0xB800  NR5G NAS >

# %%
re.compile(r".*pdu_session_estab_accept.*sd[0] = \d+ (0xd1).*sd[1] = \d+ (0x43).*sd[2] = \d+ (0xa7))"
# Out:
#   Cell In[198], line 1
#     re.compile(r".*pdu_session_estab_accept.*sd[0] = \d+ (0xd1).*sd[1] = \d+ (0x43).*sd[2] = \d+ (0xa7))"
#                                                                                                          ^
# SyntaxError: incomplete input

# %%
,flags=re.DOTALL,r'[0-9a-fA-F]+

# %%
ls =[]
print(bool(ls))
